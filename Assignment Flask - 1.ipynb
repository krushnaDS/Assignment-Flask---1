# %%
'''Q1. What is Flask Framework? What are the advantages of Flask Framework?

Flask is a web framework that allows developers to build light weight web applications quickly and easily with 
flask libraries.

Advantages of Flask:
 1. Flask is a lightweight backend framework with minimal dependencies.
 2. Flask is easy to learn because its simple and intuitive API makes it easy to learn and use for beginners.
 3. Flask is a flexible Framework because it allows you to customize and extend the framework to suit your needs easily.
 4. Flask can be used with any database like:- SQL and NoSQL and with any Frontend Technology such as React or Angular.
'''
# Out:
# 'Q1. What is Flask Framework? What are the advantages of Flask Framework?\n\nFlask is a web framework that allows developers to build light weight web applications quickly and easily with \nflask libraries.\n\nAdvantages of Flask:\n 1. Flask is a lightweight backend framework with minimal dependencies.\n 2. Flask is easy to learn because its simple and intuitive API makes it easy to learn and use for beginners.\n 3. Flask is a flexible Framework because it allows you to customize and extend the framework to suit your needs easily.\n 4. Flask can be used with any database like:- SQL and NoSQL and with any Frontend Technology such as React or Angular.\n'

# %% [markdown]
# '''Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.'''
#
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "<h1>Hello, World!</h1>"
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
#
#
# ![Screenshot%202023-08-31%20154453.png](attachment:Screenshot%202023-08-31%20154453.png)

# %%
'''Q3. What is App routing in Flask? Why do we use app routes?

The route() function of the flask class is a decorator, which tells the client/application which URL  should 
call the associated function.

route('/') - here single slash tells that URL of this code is bound to this function.

we also can write anything there & which will also bound to the respective function.
eg app.route('/test')
'''
# Out:
# "Q3. What is App routing in Flask? Why do we use app routes?\n\nThe route() function of the flask class is a decorator, which tells the client/application which URL  should \ncall the associated function.\n\nroute('/') - here single slash tells that URL of this code is bound to this function.\n\nwe also can write anything there & which will also bound to the respective function.\neg app.route('/test')\n"

# %% [markdown]
# '''Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999'''
#
# from flask import Flask , redirect , url_for , render_template
#
# app = Flask(__name__)
#
# @app.route("/welcome")
# def welcome():
#     return "<h1>Welcome to ABC Corporation.</h1>"
# @app.route("/")
# def details():
#     return "Company Name: ABC Corporation, Location: India, Contact Detail: 999-999-9999"
#
# if __name__ == "__main__":
#     jls_extract_var = "0.0.0.0"
#     app.run(host=jls_extract_var)
#
#   ![Screenshot%202023-08-31%20171025.png](attachment:Screenshot%202023-08-31%20171025.png)

# %%
'''Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.


The url_for() function is used in Flask for URL building. It takes the name of the function as its first argument and any number of keyword arguments, each corresponding to the variable part of the URL. For example, the following code would generate a URL for the user_profile() function, with the username variable set to johndoe:

from flask import url_for

def user_profile(username):
  return "This is the user profile for {}.".format(username)

url = url_for("user_profile", username="johndoe")
'''
